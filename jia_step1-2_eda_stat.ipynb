# %% [markdown]
# ## 特征分析

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.stats import chi2
import statsmodels.discrete.discrete_model as dm_

sys.path.insert(0, os.path.abspath('../'))

# %matplotlib inline

from lec1.preprocessor import *
from lec1.coverage import *

import toad
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 加载数据

# %%
data_path = f"{os.path.abspath('.')}/home-credit-default-risk/"

application_train, bureau, bureau_balance, credit_card_balance, \
installment_payments, pos_cash_balance, previous_application = load_data(data_path)

# %%
print('application_train:', application_train.shape[0], "rows and", application_train.shape[1],'columns')
print('bureau:', bureau.shape[0], "rows and", bureau.shape[1],'columns')
print('bureau_balance:', bureau_balance.shape[0], "rows and", bureau_balance.shape[1],'columns')
print('credit_card_balance:', credit_card_balance.shape[0], "rows and", credit_card_balance.shape[1],'columns')
print('POS_CASH_balance:', pos_cash_balance.shape[0], "rows and", pos_cash_balance.shape[1],'columns')
print('installments_payments:', installment_payments.shape[0], "rows and", installment_payments.shape[1],'columns')
print('previous_application:', previous_application.shape[0], "rows and", previous_application.shape[1],'columns')
# Out:
# application_train: 307511 rows and 122 columns
# bureau: 1716428 rows and 17 columns
# bureau_balance: 27299925 rows and 3 columns
# credit_card_balance: 3840312 rows and 23 columns
# POS_CASH_balance: 10001358 rows and 8 columns
# installments_payments: 13605401 rows and 8 columns
# previous_application: 1670214 rows and 37 columns

# %% [markdown]
# ## application_train数据

# %%
application_check = toad.detect(application_train)
display(application_check.head(10))
# Out:
#                        type    size missing  unique       mean_or_top1  \
# SK_ID_CURR            int64  307511   0.00%  307511             278181
# TARGET                int64  307511   0.00%       2          0.0807288
# NAME_CONTRACT_TYPE   object  307511   0.00%       2  Cash loans:90.48%
# CODE_GENDER          object  307511   0.00%       3           F:65.83%
# FLAG_OWN_CAR         object  307511   0.00%       2           N:65.99%
# FLAG_OWN_REALTY      object  307511   0.00%       2           Y:69.37%
# CNT_CHILDREN          int64  307511   0.00%      15           0.417052
# AMT_INCOME_TOTAL    float64  307511   0.00%    2548             168798
# AMT_CREDIT          float64  307511   0.00%    5603             599026
# AMT_ANNUITY         float64  307511   0.00%   13672            27108.6
#
#                               std_or_top2 min_or_top3 1%_or_top4 10%_or_top5  \
# SK_ID_CURR                         102790      100002     103590      135692
# TARGET                           0.272419           0          0           0
# NAME_CONTRACT_TYPE  Revolving loans:9.52%        None       None        None
# CODE_GENDER                      M:34.16%   XNA:0.00%       None        None
# FLAG_OWN_CAR                     Y:34.01%        None       None        None
# FLAG_OWN_REALTY                  N:30.63%        None       None        None
# CNT_CHILDREN                     0.722121           0          0           0
# AMT_INCOME_TOTAL                   237123       25650      45000       81000
# AMT_CREDIT                         402491       45000      76410      180000
# AMT_ANNUITY                       14493.7      1615.5    6182.91     11074.5
#
#                    50%_or_bottom5 75%_or_bottom4 90%_or_bottom3  \
# SK_ID_CURR                 278202         367142         420729
# TARGET                          0              0              0
# NAME_CONTRACT_TYPE           None           None           None
# CODE_GENDER                  None           None       F:65.83%
# FLAG_OWN_CAR                 None           None           None
# FLAG_OWN_REALTY              None           None           None
# CNT_CHILDREN                    0              1              2
# AMT_INCOME_TOTAL           147150         202500         270000
# AMT_CREDIT                 513531         808650    1.13375e+06
# AMT_ANNUITY                 24903          34596          45954
#
#                        99%_or_bottom2         max_or_bottom1
# SK_ID_CURR                     452713                 456255
# TARGET                              1                      1
# NAME_CONTRACT_TYPE  Cash loans:90.48%  Revolving loans:9.52%
# CODE_GENDER                  M:34.16%              XNA:0.00%
# FLAG_OWN_CAR                 N:65.99%               Y:34.01%
# FLAG_OWN_REALTY              Y:69.37%               N:30.63%
# CNT_CHILDREN                        3                     19
# AMT_INCOME_TOTAL               472500               1.17e+08
# AMT_CREDIT                  1.854e+06               4.05e+06
# AMT_ANNUITY                   70006.5                 258026

# %%
application_check_sub = toad.detect(application_train[['TARGET', 'DAYS_EMPLOYED', 'CODE_GENDER', 'OWN_CAR_AGE', 'NAME_CONTRACT_TYPE', 'FLAG_DOCUMENT_12']])
display(application_check_sub)
# Out:
#                        type    size missing  unique       mean_or_top1  \
# TARGET                int64  307511   0.00%       2          0.0807288
# DAYS_EMPLOYED         int64  307511   0.00%   12574              63815
# CODE_GENDER          object  307511   0.00%       3           F:65.83%
# OWN_CAR_AGE         float64  307511  65.99%      62            12.0611
# NAME_CONTRACT_TYPE   object  307511   0.00%       2  Cash loans:90.48%
# FLAG_DOCUMENT_12      int64  307511   0.00%       2        6.50383e-06
#
#                               std_or_top2 min_or_top3  1%_or_top4  \
# TARGET                           0.272419           0         0.0
# DAYS_EMPLOYED                      141276      -17912    -10894.9
# CODE_GENDER                      M:34.16%   XNA:0.00%         NaN
# OWN_CAR_AGE                       11.9448           0         0.0
# NAME_CONTRACT_TYPE  Revolving loans:9.52%        None         NaN
# FLAG_DOCUMENT_12               0.00255026           0         0.0
#
#                     10%_or_top5  50%_or_bottom5  75%_or_bottom4  \
# TARGET                      0.0             0.0             0.0
# DAYS_EMPLOYED           -4881.0         -1213.0          -289.0
# CODE_GENDER                 NaN             NaN             NaN
# OWN_CAR_AGE                 2.0             9.0            15.0
# NAME_CONTRACT_TYPE          NaN             NaN             NaN
# FLAG_DOCUMENT_12            0.0             0.0             0.0
#
#                    90%_or_bottom3     99%_or_bottom2         max_or_bottom1
# TARGET                          0                  1                      1
# DAYS_EMPLOYED              365243             365243                 365243
# CODE_GENDER              F:65.83%           M:34.16%              XNA:0.00%
# OWN_CAR_AGE                    22                 64                     91
# NAME_CONTRACT_TYPE           None  Cash loans:90.48%  Revolving loans:9.52%
# FLAG_DOCUMENT_12                0                  0                      1

# %%
print('top 10 features with high iv')
display(toad.quality(application_train.drop('SK_ID_CURR',axis=1),'TARGET',iv_only=True)[:10])
print('last 10 features with low iv')
display(toad.quality(application_train.drop('SK_ID_CURR',axis=1),'TARGET',iv_only=True)[-10:])
# Out:
# top 10 features with high iv
#                          iv  gini  entropy    unique
# EXT_SOURCE_3       0.332758   NaN      NaN     815.0
# EXT_SOURCE_2       0.321745   NaN      NaN  119832.0
# EXT_SOURCE_1       0.154901   NaN      NaN  114585.0
# DAYS_EMPLOYED      0.114698   NaN      NaN   12574.0
# AMT_GOODS_PRICE    0.101163   NaN      NaN    1003.0
# DAYS_BIRTH         0.090051   NaN      NaN   17460.0
# OCCUPATION_TYPE    0.082865   NaN      NaN      19.0
# ORGANIZATION_TYPE  0.073368   NaN      NaN      58.0
# AMT_CREDIT         0.068424   NaN      NaN    5603.0
# NAME_INCOME_TYPE   0.058334   NaN      NaN       8.0
# last 10 features with low iv
#                             iv  gini  entropy  unique
# FLAG_MOBIL        8.938043e-05   NaN      NaN     2.0
# FLAG_DOCUMENT_12  5.775823e-05   NaN      NaN     2.0
# FLAG_EMAIL        4.210277e-05   NaN      NaN     2.0
# FLAG_DOCUMENT_7   3.818893e-05   NaN      NaN     2.0
# FLAG_DOCUMENT_4   3.787674e-05   NaN      NaN     2.0
# FLAG_DOCUMENT_19  2.726998e-05   NaN      NaN     2.0
# FLAG_DOCUMENT_10  7.552028e-06   NaN      NaN     2.0
# FLAG_CONT_MOBILE  1.870741e-06   NaN      NaN     2.0
# FLAG_DOCUMENT_5   1.348882e-06   NaN      NaN     2.0
# FLAG_DOCUMENT_20  6.161632e-07   NaN      NaN     2.0

# %% [markdown]
# # Bureau数据

# %%
bureau_check = toad.detect(bureau)
display(bureau_check.head(10))
# Out:
#                            type     size missing   unique       mean_or_top1  \
# SK_ID_CURR                int64  1716428   0.00%   305811             278215
# SK_ID_BUREAU              int64  1716428   0.00%  1716428        5.92443e+06
# CREDIT_ACTIVE            object  1716428   0.00%        4      Closed:62.88%
# CREDIT_CURRENCY          object  1716428   0.00%        4  currency 1:99.92%
# DAYS_CREDIT               int64  1716428   0.00%     2923           -1142.11
# CREDIT_DAY_OVERDUE        int64  1716428   0.00%      942           0.818167
# DAYS_CREDIT_ENDDATE     float64  1716428   6.15%    14096            510.517
# DAYS_ENDDATE_FACT       float64  1716428  36.92%     2917           -1017.44
# AMT_CREDIT_MAX_OVERDUE  float64  1716428  65.51%    68251            3825.42
# CNT_CREDIT_PROLONG        int64  1716428   0.00%       10         0.00641041
#
#                              std_or_top2       min_or_top3        1%_or_top4  \
# SK_ID_CURR                        102939            100001            103618
# SK_ID_BUREAU                      532266             5e+06       5.01831e+06
# CREDIT_ACTIVE              Active:36.74%        Sold:0.38%    Bad debt:0.00%
# CREDIT_CURRENCY         currency 2:0.07%  currency 3:0.01%  currency 4:0.00%
# DAYS_CREDIT                      795.165             -2922             -2867
# CREDIT_DAY_OVERDUE               36.5444                 0                 0
# DAYS_CREDIT_ENDDATE              4994.22            -42060             -2571
# DAYS_ENDDATE_FACT                714.011            -42023             -2639
# AMT_CREDIT_MAX_OVERDUE            206032                 0                 0
# CNT_CREDIT_PROLONG             0.0962239                 0                 0
#
#                         10%_or_top5 50%_or_bottom5     75%_or_bottom4  \
# SK_ID_CURR                   135602         278055             367426
# SK_ID_BUREAU            5.18487e+06     5.9263e+06        6.38568e+06
# CREDIT_ACTIVE                  None           None      Closed:62.88%
# CREDIT_CURRENCY                None           None  currency 1:99.92%
# DAYS_CREDIT                   -2443           -987               -474
# CREDIT_DAY_OVERDUE                0              0                  0
# DAYS_CREDIT_ENDDATE           -1922           -330                474
# DAYS_ENDDATE_FACT             -2159           -897               -425
# AMT_CREDIT_MAX_OVERDUE            0              0                  0
# CNT_CREDIT_PROLONG                0              0                  0
#
#                           90%_or_bottom3    99%_or_bottom2    max_or_bottom1
# SK_ID_CURR                        420964            452744            456255
# SK_ID_BUREAU                 6.66063e+06       6.82513e+06       6.84346e+06
# CREDIT_ACTIVE              Active:36.74%        Sold:0.38%    Bad debt:0.00%
# CREDIT_CURRENCY         currency 2:0.07%  currency 3:0.01%  currency 4:0.00%
# DAYS_CREDIT                         -215               -38                 0
# CREDIT_DAY_OVERDUE                     0                 0              2792
# DAYS_CREDIT_ENDDATE                 1334             31029             31199
# DAYS_ENDDATE_FACT                   -178               -24                 0
# AMT_CREDIT_MAX_OVERDUE           7594.88           41988.7       1.15987e+08
# CNT_CREDIT_PROLONG                     0                 0                 9

# %%
bureau_balance_check = toad.detect(bureau_balance)
display(bureau_balance_check.head(10))
# Out:
#                   type      size missing  unique mean_or_top1 std_or_top2  \
# SK_ID_BUREAU     int64  27299925   0.00%  817395   6.0363e+06      492349
# MONTHS_BALANCE   int64  27299925   0.00%      97     -30.7417     23.8645
# STATUS          object  27299925   0.00%       8     C:49.99%    0:27.47%
#
#                 min_or_top3 1%_or_top4  10%_or_top5 50%_or_bottom5  \
# SK_ID_BUREAU    5.00171e+06  5.012e+06  5.26243e+06    6.07082e+06
# MONTHS_BALANCE          -96        -91          -68            -25
# STATUS             X:21.28%    1:0.89%      5:0.23%        1:0.89%
#
#                75%_or_bottom4 90%_or_bottom3 99%_or_bottom2 max_or_bottom1
# SK_ID_BUREAU      6.43195e+06    6.66495e+06    6.82817e+06    6.84289e+06
# MONTHS_BALANCE            -11             -4              0              0
# STATUS                5:0.23%        2:0.09%        3:0.03%        4:0.02%

# %% [markdown]
# ## 历史信用数据

# %%
credit_card_balance_check = toad.detect(credit_card_balance)
display(credit_card_balance_check.head(10))
# Out:
#                                type     size missing   unique mean_or_top1  \
# SK_ID_PREV                    int64  3840312   0.00%   104307   1.9045e+06
# SK_ID_CURR                    int64  3840312   0.00%   103558       278324
# MONTHS_BALANCE                int64  3840312   0.00%       96     -34.5219
# AMT_BALANCE                 float64  3840312   0.00%  1347904      58300.2
# AMT_CREDIT_LIMIT_ACTUAL       int64  3840312   0.00%      181       153808
# AMT_DRAWINGS_ATM_CURRENT    float64  3840312  19.52%     2267      5961.32
# AMT_DRAWINGS_CURRENT        float64  3840312   0.00%   187005      7433.39
# AMT_DRAWINGS_OTHER_CURRENT  float64  3840312  19.52%     1832       288.17
# AMT_DRAWINGS_POS_CURRENT    float64  3840312  19.52%   168748       2968.8
# AMT_INST_MIN_REGULARITY     float64  3840312   7.95%   312266       3540.2
#
#                            std_or_top2  min_or_top3   1%_or_top4  10%_or_top5  \
# SK_ID_PREV                      536469  1.00002e+06  1.01002e+06  1.17686e+06
# SK_ID_CURR                      102704       100006       103570       135912
# MONTHS_BALANCE                 26.6678          -96          -93          -76
# AMT_BALANCE                     106307      -420250            0            0
# AMT_CREDIT_LIMIT_ACTUAL         165146            0            0            0
# AMT_DRAWINGS_ATM_CURRENT       28225.7     -6827.31            0            0
# AMT_DRAWINGS_CURRENT           33846.1     -6211.62            0            0
# AMT_DRAWINGS_OTHER_CURRENT     8201.99            0            0            0
# AMT_DRAWINGS_POS_CURRENT       20796.9            0            0            0
# AMT_INST_MIN_REGULARITY        5600.15            0            0            0
#
#                            50%_or_bottom5 75%_or_bottom4 90%_or_bottom3  \
# SK_ID_PREV                    1.89712e+06    2.36933e+06    2.65201e+06
# SK_ID_CURR                         278396         367580         421492
# MONTHS_BALANCE                        -28            -11             -5
# AMT_BALANCE                             0        89046.7         180016
# AMT_CREDIT_LIMIT_ACTUAL            112500         180000         427500
# AMT_DRAWINGS_ATM_CURRENT                0              0           6750
# AMT_DRAWINGS_CURRENT                    0              0          11250
# AMT_DRAWINGS_OTHER_CURRENT              0              0              0
# AMT_DRAWINGS_POS_CURRENT                0              0              0
# AMT_INST_MIN_REGULARITY                 0        6633.91           9000
#
#                            99%_or_bottom2 max_or_bottom1
# SK_ID_PREV                    2.82532e+06     2.8435e+06
# SK_ID_CURR                         452749         456250
# MONTHS_BALANCE                         -1             -1
# AMT_BALANCE                        466295     1.5059e+06
# AMT_CREDIT_LIMIT_ACTUAL            765000       1.35e+06
# AMT_DRAWINGS_ATM_CURRENT           135000      2.115e+06
# AMT_DRAWINGS_CURRENT               157500     2.2871e+06
# AMT_DRAWINGS_OTHER_CURRENT              0    1.52985e+06
# AMT_DRAWINGS_POS_CURRENT          77080.6    2.23927e+06
# AMT_INST_MIN_REGULARITY           23312.8         202882

# %%
pos_cash_balance_check = toad.detect(pos_cash_balance)
display(pos_cash_balance_check.head(10))
# Out:
#                           type      size missing  unique   mean_or_top1  \
# SK_ID_PREV               int64  10001358   0.00%  936325    1.90322e+06
# SK_ID_CURR               int64  10001358   0.00%  337252         278404
# MONTHS_BALANCE           int64  10001358   0.00%      96       -35.0126
# CNT_INSTALMENT         float64  10001358   0.26%      73        17.0897
# CNT_INSTALMENT_FUTURE  float64  10001358   0.26%      79        10.4838
# NAME_CONTRACT_STATUS    object  10001358   0.00%       9  Active:91.50%
# SK_DPD                   int64  10001358   0.00%    3400        11.6069
# SK_DPD_DEF               int64  10001358   0.00%    2307       0.654468
#
#                            std_or_top2   min_or_top3    1%_or_top4  \
# SK_ID_PREV                      535847         1e+06    1.0119e+06
# SK_ID_CURR                      102764        100001        103540
# MONTHS_BALANCE                 26.0666           -96           -94
# CNT_INSTALMENT                 11.9951             1             4
# CNT_INSTALMENT_FUTURE          11.1091             0             0
# NAME_CONTRACT_STATUS   Completed:7.45%  Signed:0.87%  Demand:0.07%
# SK_DPD                         132.714             0             0
# SK_DPD_DEF                     32.7625             0             0
#
#                                        10%_or_top5  \
# SK_ID_PREV                             1.17690e+06
# SK_ID_CURR                                  135788
# MONTHS_BALANCE                                 -77
# CNT_INSTALMENT                                   6
# CNT_INSTALMENT_FUTURE                            0
# NAME_CONTRACT_STATUS   Returned to the store:0.05%
# SK_DPD                                           0
# SK_DPD_DEF                                       0
#
#                                     50%_or_bottom5  75%_or_bottom4  \
# SK_ID_PREV                             1.89656e+06     2.36896e+06
# SK_ID_CURR                                  278654          367429
# MONTHS_BALANCE                                 -28             -13
# CNT_INSTALMENT                                  12              24
# CNT_INSTALMENT_FUTURE                            7              14
# NAME_CONTRACT_STATUS   Returned to the store:0.05%  Approved:0.05%
# SK_DPD                                           0               0
# SK_DPD_DEF                                       0               0
#
#                              90%_or_bottom3  99%_or_bottom2 max_or_bottom1
# SK_ID_PREV                      2.65303e+06     2.82422e+06     2.8435e+06
# SK_ID_CURR                           421391          452772         456255
# MONTHS_BALANCE                           -6              -2             -1
# CNT_INSTALMENT                           36              60             92
# CNT_INSTALMENT_FUTURE                    24              53             85
# NAME_CONTRACT_STATUS   Amortized debt:0.01%  Canceled:0.00%      XNA:0.00%
# SK_DPD                                    0             235           4231
# SK_DPD_DEF                                0               1           3595

# %%
installment_payments_check = toad.detect(installment_payments)
display(installment_payments_check.head(10))
# Out:
#                            type      size missing  unique  mean_or_top1  \
# SK_ID_PREV                int64  13605401   0.00%  997752  1.903365e+06
# SK_ID_CURR                int64  13605401   0.00%  339587  2.784449e+05
# NUM_INSTALMENT_VERSION  float64  13605401   0.00%      65  8.566373e-01
# NUM_INSTALMENT_NUMBER     int64  13605401   0.00%     277  1.887090e+01
# DAYS_INSTALMENT         float64  13605401   0.00%    2922 -1.042270e+03
# DAYS_ENTRY_PAYMENT      float64  13605401   0.02%    3039 -1.051114e+03
# AMT_INSTALMENT          float64  13605401   0.00%  902539  1.705091e+04
# AMT_PAYMENT             float64  13605401   0.02%  944235  1.723822e+04
#
#                           std_or_top2  min_or_top3   1%_or_top4  10%_or_top5  \
# SK_ID_PREV              536202.905546    1000001.0  1011180.000  1176563.000
# SK_ID_CURR              102718.310411     100001.0   103583.000   135870.000
# NUM_INSTALMENT_VERSION       1.035216          0.0        0.000        0.000
# NUM_INSTALMENT_NUMBER       26.664067          1.0        1.000        2.000
# DAYS_INSTALMENT            800.946284      -2922.0    -2832.000    -2307.000
# DAYS_ENTRY_PAYMENT         800.585883      -4921.0    -2837.000    -2316.000
# AMT_INSTALMENT           50570.254429          0.0       13.275      717.705
# AMT_PAYMENT              54735.783981          0.0        3.780      331.830
#
#                         50%_or_bottom5  75%_or_bottom4  90%_or_bottom3  \
# SK_ID_PREV                 1896520.000     2369094.000     2652602.000
# SK_ID_CURR                  278685.000      367530.000      421540.000
# NUM_INSTALMENT_VERSION           1.000           1.000           1.000
# NUM_INSTALMENT_NUMBER            8.000          19.000          56.000
# DAYS_INSTALMENT               -818.000        -361.000        -150.000
# DAYS_ENTRY_PAYMENT            -827.000        -370.000        -159.000
# AMT_INSTALMENT                8884.080       16710.210       31415.175
# AMT_PAYMENT                   8125.515       16108.425       31179.915
#
#                         99%_or_bottom2  max_or_bottom1
# SK_ID_PREV                2.824545e+06     2843499.000
# SK_ID_CURR                4.528020e+05      456255.000
# NUM_INSTALMENT_VERSION    4.000000e+00         178.000
# NUM_INSTALMENT_NUMBER     1.210000e+02         277.000
# DAYS_INSTALMENT          -2.100000e+01          -1.000
# DAYS_ENTRY_PAYMENT       -2.800000e+01          -1.000
# AMT_INSTALMENT            1.460687e+05     3771487.845
# AMT_PAYMENT               1.780040e+05     3771487.845

# %%
previous_application_check = toad.detect(previous_application)
display(previous_application_check.head(10))
# Out:
#                                type     size missing   unique  \
# SK_ID_PREV                    int64  1670214   0.00%  1670214
# SK_ID_CURR                    int64  1670214   0.00%   338857
# NAME_CONTRACT_TYPE           object  1670214   0.00%        4
# AMT_ANNUITY                 float64  1670214  22.29%   357959
# AMT_APPLICATION             float64  1670214   0.00%    93885
# AMT_CREDIT                  float64  1670214   0.00%    86803
# AMT_DOWN_PAYMENT            float64  1670214  53.64%    29278
# AMT_GOODS_PRICE             float64  1670214  23.08%    93885
# WEEKDAY_APPR_PROCESS_START   object  1670214   0.00%        7
# HOUR_APPR_PROCESS_START       int64  1670214   0.00%       24
#
#                                  mean_or_top1            std_or_top2  \
# SK_ID_PREV                        1.92309e+06                 532598
# SK_ID_CURR                             278357                 102815
# NAME_CONTRACT_TYPE          Cash loans:44.76%  Consumer loans:43.66%
# AMT_ANNUITY                           15955.1                14782.1
# AMT_APPLICATION                        175234                 292780
# AMT_CREDIT                             196114                 318575
# AMT_DOWN_PAYMENT                       6697.4                20921.5
# AMT_GOODS_PRICE                        227847                 315397
# WEEKDAY_APPR_PROCESS_START     TUESDAY:15.27%       WEDNESDAY:15.27%
# HOUR_APPR_PROCESS_START               12.4842                3.33403
#
#                                        min_or_top3     1%_or_top4  \
# SK_ID_PREV                                   1e+06    1.01857e+06
# SK_ID_CURR                                  100001         103494
# NAME_CONTRACT_TYPE          Revolving loans:11.57%      XNA:0.02%
# AMT_ANNUITY                                      0        2137.18
# AMT_APPLICATION                                  0              0
# AMT_CREDIT                                       0              0
# AMT_DOWN_PAYMENT                              -0.9              0
# AMT_GOODS_PRICE                                  0          15300
# WEEKDAY_APPR_PROCESS_START           MONDAY:15.18%  FRIDAY:15.09%
# HOUR_APPR_PROCESS_START                          0              5
#
#                                 10%_or_top5 50%_or_bottom5     75%_or_bottom4  \
# SK_ID_PREV                      1.18503e+06    1.92311e+06        2.38428e+06
# SK_ID_CURR                           135738         278714             367514
# NAME_CONTRACT_TYPE                     None           None  Cash loans:44.76%
# AMT_ANNUITY                         3817.53          11250            20658.4
# AMT_APPLICATION                           0          71046             180360
# AMT_CREDIT                                0          80541             216418
# AMT_DOWN_PAYMENT                          0           1638               7740
# AMT_GOODS_PRICE                       30555         112320             234000
# WEEKDAY_APPR_PROCESS_START  THURSDAY:14.91%  MONDAY:15.18%      FRIDAY:15.09%
# HOUR_APPR_PROCESS_START                   8             12                 15
#
#                                    90%_or_bottom3          99%_or_bottom2  \
# SK_ID_PREV                            2.66086e+06             2.82691e+06
# SK_ID_CURR                                 421359                  452785
# NAME_CONTRACT_TYPE          Consumer loans:43.66%  Revolving loans:11.57%
# AMT_ANNUITY                               34703.8                 69685.8
# AMT_APPLICATION                            450000                1.35e+06
# AMT_CREDIT                                 533160             1.51538e+06
# AMT_DOWN_PAYMENT                            17109                 65930.9
# AMT_GOODS_PRICE                            585000               1.395e+06
# WEEKDAY_APPR_PROCESS_START        THURSDAY:14.91%         SATURDAY:14.41%
# HOUR_APPR_PROCESS_START                        17                      20
#
#                            max_or_bottom1
# SK_ID_PREV                    2.84538e+06
# SK_ID_CURR                         456255
# NAME_CONTRACT_TYPE              XNA:0.02%
# AMT_ANNUITY                        418058
# AMT_APPLICATION               6.90516e+06
# AMT_CREDIT                    6.90516e+06
# AMT_DOWN_PAYMENT              3.06004e+06
# AMT_GOODS_PRICE               6.90516e+06
# WEEKDAY_APPR_PROCESS_START   SUNDAY:9.86%
# HOUR_APPR_PROCESS_START                23

# %% [markdown]
# # 高缺失值特征要去掉
# # 过于不均衡的特征去掉
# # 低IV的特征去掉
# * 使用toad的quality check 设置 iv_only 来只计算IV
